# %% [markdown]
# <img src='11.jpg'>

# %%
#pip install pycaret
#Projeyi AutoMl ile çözeceğim için en başta colab da importları yaptık

# %%
import pandas as pd

# %%
#Regression AutoMl

# %%
from pycaret.regression import*

# %%
df=pd.read_csv("profiles.csv")

# %%
df.head()
# Out:
#     age       body_type               diet    drinks      drugs  \
# 0  22.0  a little extra  strictly anything  socially      never
# 1  35.0         average       mostly other     often  sometimes
# 2  38.0            thin           anything  socially        NaN
# 3  23.0            thin         vegetarian  socially        NaN
# 4  29.0        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# 4  creating imagery to look at:<br />\nhttp://bag...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
# 3                  socially awkward but i do my best
# 4            i smile a lot and my inquisitive nature
#
#                                               essay4  \
# 0  books:<br />\nabsurdistan, the republic, of mi...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
# 3  bataille, celine, beckett. . .<br />\nlynch, j...
# 4  music: bands, rappers, musicians<br />\nat the...
#
#                                               essay5  \
# 0  food.<br />\nwater.<br />\ncell phone.<br />\n...
# 1  delicious porkness in all of its glories.<br /...
# 2  movement<br />\nconversation<br />\ncreation<b...
# 3                                                NaN
# 4                                                NaN
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
# 3   cats and german philosophy
# 4                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay9            ethnicity  \
# 0  you want to be swept off your feet!<br />\nyou...         asian, white
# 1                                                NaN                white
# 2  you are bright, open, intense, silly, ironic, ...                  NaN
# 3                              you feel so inclined.                white
# 4                                                NaN  asian, black, other
#
#    height   income                          job       last_online  \
# 0    75.0     -1.0               transportation  2012-06-28-20-30
# 1    70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2    68.0     -1.0                          NaN  2012-06-27-09-10
# 3    71.0  20000.0                      student  2012-06-28-14-22
# 4    66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60552 entries, 0 to 60551
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    8666 non-null   object
#  2   diet         5761 non-null   object
#  3   drinks       9012 non-null   object
#  4   drugs        7215 non-null   object
#  5   education    8459 non-null   object
#  6   essay0       8667 non-null   object
#  7   essay1       8347 non-null   object
#  8   essay2       8049 non-null   object
#  9   essay3       7690 non-null   object
#  10  essay4       7879 non-null   object
#  11  essay5       7814 non-null   object
#  12  essay6       7352 non-null   object
#  13  essay7       7553 non-null   object
#  14  essay8       6361 non-null   object
#  15  essay9       7554 non-null   object
#  16  ethnicity    8565 non-null   object
#  17  height       9514 non-null   float64
#  18  income       9514 non-null   float64
#  19  job          8183 non-null   object
#  20  last_online  9514 non-null   object
#  21  location     9514 non-null   object
#  22  offspring    3886 non-null   object
#  23  orientation  9514 non-null   object
#  24  pets         6352 non-null   object
#  25  religion     6261 non-null   object
#  26  sex          9514 non-null   object
#  27  sign         7776 non-null   object
#  28  smokes       8596 non-null   object
#  29  speaks       9508 non-null   object
#  30  status       9514 non-null   object
# dtypes: float64(3), object(28)
# memory usage: 14.3+ MB

# %%
df.isnull().sum()
# Out:
# age            51038
# body_type      51886
# diet           54791
# drinks         51540
# drugs          53337
# education      52093
# essay0         51885
# essay1         52205
# essay2         52503
# essay3         52862
# essay4         52673
# essay5         52738
# essay6         53200
# essay7         52999
# essay8         54191
# essay9         52998
# ethnicity      51987
# height         51038
# income         51038
# job            52369
# last_online    51038
# location       51038
# offspring      56666
# orientation    51038
# pets           54200
# religion       54291
# sex            51038
# sign           52776
# smokes         51956
# speaks         51044
# status         51038
# dtype: int64

# %%
#İmporting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
##from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## EDA Düzenlemeler

# %%
df.sample(7)
# Out:
#         age body_type             diet    drinks  drugs  \
# 6159   24.0   average  mostly anything  socially    NaN
# 526    42.0  athletic  mostly anything  socially  never
# 10096   NaN       NaN              NaN       NaN    NaN
# 20120   NaN       NaN              NaN       NaN    NaN
# 46682   NaN       NaN              NaN       NaN    NaN
# 18939   NaN       NaN              NaN       NaN    NaN
# 60022   NaN       NaN              NaN       NaN    NaN
#
#                                education  \
# 6159   graduated from college/university
# 526    dropped out of college/university
# 10096                                NaN
# 20120                                NaN
# 46682                                NaN
# 18939                                NaN
# 60022                                NaN
#
#                                                   essay0  \
# 6159   um so i dunno what i'm exactly suppose to put ...
# 526                                                  NaN
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay1  \
# 6159   right now just working and getting myself read...
# 526    just opened up my 2nd restaurant with my busin...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay2  \
# 6159   installing car audio systems. it's been a hobb...
# 526    making people smile and making sure they leave...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay3  \
# 6159   i really don't know. maybe that i'm tall? or i...
# 526    usually they notice i'm a big guy with presenc...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay4  \
# 6159   favorite books : big bad wolf, enders games, t...
# 526    im a total foodie. high brow, ghetto cheap, yo...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay5  \
# 6159   music<br />\nadventures<br />\nsmart phone<br ...
# 526    i cannot live without my family , my close fri...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay6  \
# 6159   the future and what i'd like to accomplish. wh...
# 526    i spend allot of time thinking about my parent...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay7  \
# 6159   recently i've been working a lot. so on friday...
# 526    lately i have been working late due to the bus...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay8  \
# 6159                                                 NaN
# 526    big guys do cry. we won't admit it...but we do...
# 10096                                                NaN
# 20120                                                NaN
# 46682                                                NaN
# 18939                                                NaN
# 60022                                                NaN
#
#                                                   essay9         ethnicity  \
# 6159   you read everything i wrote.<br />\n<br />\nyo...      black, other
# 526    if your willing to meet a genuine nice / old s...  hispanic / latin
# 10096                                                NaN               NaN
# 20120                                                NaN               NaN
# 46682                                                NaN               NaN
# 18939                                                NaN               NaN
# 60022                                                NaN               NaN
#
#        height  income                          job       last_online  \
# 6159     72.0    -1.0  sales / marketing / biz dev  2012-06-26-07-31
# 526      72.0    -1.0                        other  2012-06-25-19-26
# 10096     NaN     NaN                          NaN               NaN
# 20120     NaN     NaN                          NaN               NaN
# 46682     NaN     NaN                          NaN               NaN
# 18939     NaN     NaN                          NaN               NaN
# 60022     NaN     NaN                          NaN               NaN
#
#                         location offspring orientation        pets  \
# 6159        pacifica, california       NaN    straight  likes dogs
# 526    san francisco, california       NaN    straight         NaN
# 10096                        NaN       NaN         NaN         NaN
# 20120                        NaN       NaN         NaN         NaN
# 46682                        NaN       NaN         NaN         NaN
# 18939                        NaN       NaN         NaN         NaN
# 60022                        NaN       NaN         NaN         NaN
#
#                                         religion  sex  \
# 6159   catholicism and somewhat serious about it    m
# 526                  other and laughing about it    m
# 10096                                        NaN  NaN
# 20120                                        NaN  NaN
# 46682                                        NaN  NaN
# 18939                                        NaN  NaN
# 60022                                        NaN  NaN
#
#                                            sign smokes  \
# 6159   gemini and it&rsquo;s fun to think about     no
# 526          cancer but it doesn&rsquo;t matter     no
# 10096                                       NaN    NaN
# 20120                                       NaN    NaN
# 46682                                       NaN    NaN
# 18939                                       NaN    NaN
# 60022                                       NaN    NaN
#
#                           speaks  status
# 6159   english, other (fluently)  single
# 526                      english  single
# 10096                        NaN     NaN
# 20120                        NaN     NaN
# 46682                        NaN     NaN
# 18939                        NaN     NaN
# 60022                        NaN     NaN

# %%
#tekrarlanan satır sayısını bulmak için kullanılır.
df.duplicated().sum()
# Out:
# 51037

# %%
#tekrar eden veriler çok onları drop etmeliyiz
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
#tekrar eden ifadeleri kaldırdık
# Out:
# 0

# %%
df.shape
# Out:
# (9515, 31)

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks          503
# drugs          2300
# education      1056
# essay0          848
# essay1         1168
# essay2         1466
# essay3         1825
# essay4         1636
# essay5         1701
# essay6         2163
# essay7         1962
# essay8         3154
# essay9         1961
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# sign           1739
# smokes          919
# speaks            7
# status            1
# dtype: int64

# %%
df.describe()
# Out:
#                age       height          income
# count  9514.000000  9514.000000     9514.000000
# mean     32.084192    68.337398    18887.145155
# std       9.445488     3.905229    91428.807808
# min      18.000000    36.000000       -1.000000
# 25%      25.000000    66.000000       -1.000000
# 50%      30.000000    68.000000       -1.000000
# 75%      36.000000    71.000000       -1.000000
# max     110.000000    95.000000  1000000.000000

# %%
df.corr()
# Out:
#              age    height    income
# age     1.000000 -0.022078  0.011424
# height -0.022078  1.000000  0.073105
# income  0.011424  0.073105  1.000000

# %%
#regression ve classification için boşlukları doldurmalı ve objectleri inte ve floata cevirmeliyiz

# %%
kaldır=['essay0',  'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']
df.drop(kaldır, inplace=True, axis=1)

# %%
df.head()
# Out:
#     age       body_type               diet    drinks      drugs  \
# 0  22.0  a little extra  strictly anything  socially      never
# 1  35.0         average       mostly other     often  sometimes
# 2  38.0            thin           anything  socially        NaN
# 3  23.0            thin         vegetarian  socially        NaN
# 4  29.0        athletic                NaN  socially      never
#
#                            education            ethnicity  height   income  \
# 0      working on college/university         asian, white    75.0     -1.0
# 1              working on space camp                white    70.0  80000.0
# 2     graduated from masters program                  NaN    68.0     -1.0
# 3      working on college/university                white    71.0  20000.0
# 4  graduated from college/university  asian, black, other    66.0     -1.0
#
#                            job       last_online  \
# 0               transportation  2012-06-28-20-30
# 1         hospitality / travel  2012-06-29-21-41
# 2                          NaN  2012-06-27-09-10
# 3                      student  2012-06-28-14-22
# 4  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df.isnull().mean().sort_values(ascending=False) #boş verilerin yüzdesi büyükten küçüğe
# Out:
# offspring      0.591592
# diet           0.394535
# religion       0.341986
# pets           0.332422
# drugs          0.241724
# sign           0.182764
# job            0.139989
# education      0.110983
# ethnicity      0.099842
# smokes         0.096584
# body_type      0.089228
# drinks         0.052864
# speaks         0.000736
# age            0.000105
# sex            0.000105
# last_online    0.000105
# orientation    0.000105
# location       0.000105
# income         0.000105
# height         0.000105
# status         0.000105
# dtype: float64

# %%
df.drinks.value_counts().sort_values(ascending=False)  #içmek
# Out:
# socially       6679
# rarely          911
# often           809
# not at all      509
# very often       54
# desperately      50
# Name: drinks, dtype: int64

# %%
df.drugs.value_counts().sort_values(ascending=False)  #ilaç
# Out:
# never        5972
# sometimes    1181
# often          62
# Name: drugs, dtype: int64

# %%
df.smokes.value_counts().sort_values(ascending=False) #sigara kullanımı
# Out:
# no                7011
# sometimes          565
# when drinking      480
# yes                307
# trying to quit     233
# Name: smokes, dtype: int64

# %%
df["drinks"]=df["drinks"].map({"not at all":0, "rarely":1, "socially":2, "often":3, "very often":4, "desperately":5})
df["drugs"] = df["drugs"].map({"never":0, "sometimes":1, "often":2})
df["smokes"] = df["smokes"].map({"no":0, "trying to quit":1, "sometimes":2, "when drinking":3, "yes":4})

# %%
df["drinks"] = df["drinks"].fillna("0")
df["drugs"] = df["drugs"].fillna("0")
df["smokes"] = df["smokes"].fillna("0")

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks            0
# drugs             0
# education      1056
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# sign           1739
# smokes            0
# speaks            7
# status            1
# dtype: int64

# %%
df.body_type.value_counts().sort_values(ascending=False) #vücüt tiplerini sadeleştirelim
# Out:
# average           2274
# fit               2040
# athletic          1888
# thin               740
# curvy              626
# a little extra     430
# skinny             269
# full figured       181
# overweight          69
# jacked              64
# used up             47
# rather not say      38
# Name: body_type, dtype: int64

# %%
new_body_type={"average":"fit",
              "fit":"fit",
              "athletic":"fit",
              "thin":"fit",
              "curvy":"curvy",
              "a little extra":"curvy",
              "skinny":"fit",
              "full figured":"curvy",
              "overweight":"bad",
              "jacked":"bad",
              "used up":"bad",
              "rather not say":"curvy"
             }
df.body_type.replace(new_body_type,inplace=True)

# %%
sns.countplot(x=df["body_type"])
# Out:
# <Axes: xlabel='body_type', ylabel='count'>

# %%
df.diet.value_counts().sort_values(ascending=False)  #yeme kültürü
# Out:
# mostly anything        2621
# anything               1067
# strictly anything       835
# mostly vegetarian       568
# mostly other            154
# strictly vegetarian     135
# vegetarian              111
# strictly other           64
# other                    52
# mostly vegan             52
# strictly vegan           40
# vegan                    28
# mostly halal             13
# mostly kosher            12
# strictly halal            4
# strictly kosher           2
# kosher                    2
# halal                     1
# Name: diet, dtype: int64

# %%
df['diet']=df.diet.replace({'mostly':'', 'strictly':''}, regex=True).str.strip()

## Baştaki Çoğunlukla veya Kesinlikle bilg. kaldırıyoruz.

# %%
df.diet.value_counts().sort_values(ascending=False)  #yeme kültürü
# Out:
# anything      4523
# vegetarian     814
# other          270
# vegan          120
# halal           18
# kosher          16
# Name: diet, dtype: int64

# %%
sns.countplot(x=df["diet"])
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
df.education.value_counts().sort_values(ascending=False)
# Out:
# graduated from college/university    3770
# graduated from masters program       1402
# working on college/university         969
# working on masters program            251
# graduated from two-year college       245
# graduated from high school            205
# graduated from ph.d program           203
# graduated from law school             177
# working on two-year college           159
# working on ph.d program               159
# dropped out of college/university     149
# college/university                    134
# graduated from space camp             104
# dropped out of space camp              87
# graduated from med school              73
# working on space camp                  73
# working on law school                  55
# two-year college                       43
# working on med school                  41
# dropped out of two-year college        34
# masters program                        21
# working on high school                 20
# dropped out of ph.d program            19
# dropped out of masters program         16
# dropped out of high school             13
# high school                            13
# space camp                             10
# ph.d program                            5
# law school                              4
# dropped out of law school               3
# dropped out of med school               2
# Name: education, dtype: int64

# %%
df["education"].replace({"working on":"student","graduated from":"graduated","dropped out":"dropped"},regex=True)
df["education"]=df["education"].str.split().str[0]
df["education"].replace({"college/university":"student","two-year":"student","masters":"student","working":"student","space":"student"},regex=True)
# Out:
# 0         student
# 1         student
# 2       graduated
# 3         student
# 4       graduated
#           ...
# 9510          NaN
# 9511      dropped
# 9512      student
# 9513    graduated
# 9514          NaN
# Name: education, Length: 9515, dtype: object

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks            0
# drugs             0
# education      1056
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# sign           1739
# smokes            0
# speaks            7
# status            1
# dtype: int64

# %%
df.education.value_counts().sort_values(ascending=False)
# Out:
# graduated             6179
# working               1727
# dropped                323
# college/university     134
# two-year                43
# masters                 21
# high                    13
# space                   10
# ph.d                     5
# law                      4
# Name: education, dtype: int64

# %%
sns.countplot(x=df["education"])
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
df.job.value_counts().sort_values(ascending=False)
# Out:
# other                                1153
# student                               807
# science / tech / engineering          780
# artistic / musical / writer           715
# computer / hardware / software        709
# sales / marketing / biz dev           709
# medicine / health                     613
# education / academia                  538
# executive / management                378
# entertainment / media                 356
# banking / financial / real estate     353
# hospitality / travel                  217
# law / legal services                  200
# construction / craftsmanship          178
# clerical / administrative             117
# political / government                105
# rather not say                         68
# transportation                         64
# unemployed                             56
# retired                                38
# military                               29
# Name: job, dtype: int64

# %%
df["job"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df["religion"]=df["religion"].str.split().str[0]
 #"religion" sütunundaki değerleri boşluk karakterine göre böler ve her bir değer için sadece ilk kelimeyi alarak "religion" sütununu günceller

# %%
df.religion.value_counts().sort_values(ascending=False)
# Out:
# agnosticism     1381
# other           1193
# atheism         1131
# christianity     905
# catholicism      762
# judaism          490
# buddhism         288
# hinduism          82
# islam             29
# Name: religion, dtype: int64

# %%
df["religion"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks            0
# drugs             0
# education      1056
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# sign           1739
# smokes            0
# speaks            7
# status            1
# dtype: int64

# %%
df['speaks'].unique()
# Out:
# array(['english', 'english (fluently), spanish (poorly), french (poorly)',
#        'english, french, c++', ...,
#        'english (fluently), french (okay), spanish (poorly), sign language (poorly)',
#        'english (fluently), spanish, swedish',
#        'english (fluently), french (okay), swedish (poorly)'],
#       dtype=object)

# %%
df["number_of_fluent_languages"]=df.speaks.str.count("fluently")
df["number_of_fluent_languages"].replace(0,1,regex=True,inplace=True)
df["number_of_poorly_languages"]=df.speaks.str.count("poorly")
df.drop("speaks",axis=1,inplace=True)

# %%
df
# Out:
#        age body_type        diet drinks drugs  education            ethnicity  \
# 0     22.0     curvy    anything    2.0   0.0    working         asian, white
# 1     35.0       fit       other    3.0   1.0    working                white
# 2     38.0       fit    anything    2.0     0  graduated                  NaN
# 3     23.0       fit  vegetarian    2.0     0    working                white
# 4     29.0       fit         NaN    2.0   0.0  graduated  asian, black, other
# ...    ...       ...         ...    ...   ...        ...                  ...
# 9510  31.0       fit    anything    2.0   1.0        NaN                white
# 9511  34.0       fit         NaN    2.0     0    dropped                white
# 9512  29.0       fit    anything    1.0   0.0   two-year                white
# 9513  49.0       bad         NaN    1.0   0.0  graduated                white
# 9514   NaN       NaN         NaN      0     0        NaN                  NaN
#
#       height   income                          job       last_online  \
# 0       75.0     -1.0               transportation  2012-06-28-20-30
# 1       70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2       68.0     -1.0                          NaN  2012-06-27-09-10
# 3       71.0  20000.0                      student  2012-06-28-14-22
# 4       66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
# ...      ...      ...                          ...               ...
# 9510    72.0     -1.0         hospitality / travel  2012-04-05-21-46
# 9511    71.0     -1.0         hospitality / travel  2012-04-28-12-42
# 9512    70.0     -1.0                          NaN  2012-03-01-15-17
# 9513    64.0     -1.0               rather not say  2012-06-14-15-14
# 9514     NaN      NaN                          NaN               NaN
#
#                              location  \
# 0     south san francisco, california
# 1                 oakland, california
# 2           san francisco, california
# 3                berkeley, california
# 4           san francisco, california
# ...                               ...
# 9510        san francisco, california
# 9511        san francisco, california
# 9512        san francisco, california
# 9513        castro valley, california
# 9514                              NaN
#
#                                               offspring orientation  \
# 0          doesn&rsquo;t have kids, but might want them    straight
# 1          doesn&rsquo;t have kids, but might want them    straight
# 2                                                   NaN    straight
# 3                               doesn&rsquo;t want kids    straight
# 4                                                   NaN    straight
# ...                                                 ...         ...
# 9510                                                NaN         gay
# 9511                            doesn&rsquo;t want kids         gay
# 9512  doesn&rsquo;t have kids, and doesn&rsquo;t wan...         gay
# 9513                                                NaN    straight
# 9514                                                NaN         NaN
#
#                            pets     religion  sex  \
# 0     likes dogs and likes cats  agnosticism    m
# 1     likes dogs and likes cats  agnosticism    m
# 2                      has cats          NaN    m
# 3                    likes cats          NaN    m
# 4     likes dogs and likes cats          NaN    m
# ...                         ...          ...  ...
# 9510                        NaN      atheism    m
# 9511    likes dogs and has cats      atheism    m
# 9512    likes dogs and has cats          NaN    m
# 9513  likes dogs and likes cats          NaN    f
# 9514                        NaN          NaN  NaN
#
#                                           sign smokes     status  \
# 0                                       gemini    2.0     single
# 1                                       cancer    0.0     single
# 2           pisces but it doesn&rsquo;t matter    0.0  available
# 3                                       pisces    0.0     single
# 4                                     aquarius    0.0     single
# ...                                        ...    ...        ...
# 9510       scorpio but it doesn&rsquo;t matter    2.0     single
# 9511     leo and it&rsquo;s fun to think about    3.0     single
# 9512                                     aries    0.0     single
# 9513  pisces and it&rsquo;s fun to think about    0.0     single
# 9514                                       NaN      0        NaN
#
#       number_of_fluent_languages  number_of_poorly_languages
# 0                            1.0                         0.0
# 1                            1.0                         2.0
# 2                            1.0                         0.0
# 3                            1.0                         1.0
# 4                            1.0                         0.0
# ...                          ...                         ...
# 9510                         1.0                         0.0
# 9511                         1.0                         0.0
# 9512                         1.0                         1.0
# 9513                         1.0                         0.0
# 9514                         NaN                         NaN
#
# [9515 rows x 22 columns]

# %%
sns.countplot(x=df["number_of_poorly_languages"])
# Out:
# <Axes: xlabel='number_of_poorly_languages', ylabel='count'>

# %%
sns.countplot(x=df["number_of_fluent_languages"])
# Out:
# <Axes: xlabel='number_of_fluent_languages', ylabel='count'>

# %%
df.status.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#hayvanın türü değil sahip olup olmadığı Önemli
df['has_animals'] = df.pets.str.contains('has')

# %%
df.pets.str.contains('1', na=True)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9510     True
# 9511    False
# 9512    False
# 9513    False
# 9514     True
# Name: pets, Length: 9515, dtype: bool

# %%
df['has_animals'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                  NaN
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit         NaN    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job       last_online  \
# 0    75.0     -1.0               transportation  2012-06-28-20-30
# 1    70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2    68.0     -1.0                          NaN  2012-06-27-09-10
# 3    71.0  20000.0                      student  2012-06-28-14-22
# 4    66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets     religion sex  \
# 0  likes dogs and likes cats  agnosticism   m
# 1  likes dogs and likes cats  agnosticism   m
# 2                   has cats          NaN   m
# 3                 likes cats          NaN   m
# 4  likes dogs and likes cats          NaN   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#    number_of_fluent_languages  number_of_poorly_languages has_animals
# 0                         1.0                         0.0       False
# 1                         1.0                         2.0       False
# 2                         1.0                         0.0        True
# 3                         1.0                         1.0       False
# 4                         1.0                         0.0       False

# %%
df.drop("pets",axis=1,inplace=True)

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                  NaN
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit         NaN    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job       last_online  \
# 0    75.0     -1.0               transportation  2012-06-28-20-30
# 1    70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2    68.0     -1.0                          NaN  2012-06-27-09-10
# 3    71.0  20000.0                      student  2012-06-28-14-22
# 4    66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation     religion sex  \
# 0  doesn&rsquo;t have kids, but might want them    straight  agnosticism   m
# 1  doesn&rsquo;t have kids, but might want them    straight  agnosticism   m
# 2                                           NaN    straight          NaN   m
# 3                       doesn&rsquo;t want kids    straight          NaN   m
# 4                                           NaN    straight          NaN   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#    number_of_fluent_languages  number_of_poorly_languages has_animals
# 0                         1.0                         0.0       False
# 1                         1.0                         2.0       False
# 2                         1.0                         0.0        True
# 3                         1.0                         1.0       False
# 4                         1.0                         0.0       False

# %%
#çocuğa sahip mi değil mi
df['has_kids'] = df.offspring.str.contains('has')

# %%
df.offspring.str.contains('1', na=True)
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9510     True
# 9511    False
# 9512    False
# 9513     True
# 9514     True
# Name: offspring, Length: 9515, dtype: bool

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                  NaN
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit         NaN    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job       last_online  \
# 0    75.0     -1.0               transportation  2012-06-28-20-30
# 1    70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2    68.0     -1.0                          NaN  2012-06-27-09-10
# 3    71.0  20000.0                      student  2012-06-28-14-22
# 4    66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation     religion sex  \
# 0  doesn&rsquo;t have kids, but might want them    straight  agnosticism   m
# 1  doesn&rsquo;t have kids, but might want them    straight  agnosticism   m
# 2                                           NaN    straight          NaN   m
# 3                       doesn&rsquo;t want kids    straight          NaN   m
# 4                                           NaN    straight          NaN   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#    number_of_fluent_languages  number_of_poorly_languages has_animals has_kids
# 0                         1.0                         0.0       False    False
# 1                         1.0                         2.0       False    False
# 2                         1.0                         0.0        True      NaN
# 3                         1.0                         1.0       False    False
# 4                         1.0                         0.0       False      NaN

# %%
df.drop("offspring",axis=1,inplace=True)

# %%
df.sample()
# Out:
#        age body_type      diet drinks drugs  education ethnicity  height  \
# 4361  24.0       fit  anything    2.0     0  graduated     white    69.0
#
#       income                           job       last_online  \
# 4361    -1.0  science / tech / engineering  2012-06-29-22-18
#
#                        location orientation religion sex sign smokes  status  \
# 4361  san francisco, california    bisexual  atheism   f  NaN    2.0  single
#
#       number_of_fluent_languages  number_of_poorly_languages has_animals  \
# 4361                         1.0                         0.0         NaN
#
#      has_kids
# 4361    False

# %%
#classification için jenerasyon sutunu tanımlayıp, ekliyoruz

# %%
# 0: Millenial: 18-32, Gen X-er: 33-47, Boomers:48-70
df.loc[df[df.age<=70].index, 'generation'] = 'Boomers'
df.loc[df[df.age<=47].index, 'generation'] = 'Gen X-er'
df.loc[df[df.age<=32].index, 'generation'] = 'Millennial'

# %%
df.sample(5)
# Out:
#        age body_type      diet drinks drugs  education         ethnicity  \
# 1641  32.0       fit  anything    1.0   0.0  graduated  hispanic / latin
# 533   28.0       fit  anything    2.0     0  graduated             asian
# 4024  41.0       fit  anything    2.0   0.0  graduated             white
# 7449  38.0       fit  anything    2.0   0.0  graduated  pacific islander
# 8329  31.0       fit  anything    1.0   1.0        NaN             white
#
#       height   income                             job       last_online  \
# 1641    68.0  80000.0  computer / hardware / software  2012-06-29-00-00
# 533     69.0     -1.0                           other  2012-06-29-03-55
# 4024    66.0     -1.0          executive / management  2012-06-20-23-02
# 7449    60.0     -1.0                             NaN  2012-06-23-00-03
# 8329    71.0     -1.0    construction / craftsmanship  2012-06-29-10-02
#
#                        location orientation      religion sex  \
# 1641        oakland, california    straight           NaN   m
# 533   san francisco, california    straight         other   f
# 4024  san francisco, california    straight           NaN   f
# 7449  san francisco, california    straight  christianity   f
# 8329  san francisco, california         gay           NaN   m
#
#                                           sign smokes  status  \
# 1641       scorpio but it doesn&rsquo;t matter    0.0  single
# 533    aries and it&rsquo;s fun to think about    2.0  single
# 4024       scorpio but it doesn&rsquo;t matter    0.0  single
# 7449  taurus and it&rsquo;s fun to think about    0.0  single
# 8329                                     libra    4.0  single
#
#       number_of_fluent_languages  number_of_poorly_languages has_animals  \
# 1641                         2.0                         0.0       False
# 533                          1.0                         0.0         NaN
# 4024                         1.0                         2.0         NaN
# 7449                         1.0                         2.0        True
# 8329                         1.0                         0.0       False
#
#      has_kids  generation
# 1641      NaN  Millennial
# 533      True  Millennial
# 4024      NaN    Gen X-er
# 7449    False    Gen X-er
# 8329    False  Millennial

# %%
df["generation"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df.age.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#bir veri çerçevesindeki tüm NaN (boş) değerleri her sütundaki en yaygın değerle doldurmak için kullanılır
df=df.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
df.isnull().sum()
# Out:
# age                           0
# body_type                     0
# diet                          0
# drinks                        0
# drugs                         0
# education                     0
# ethnicity                     0
# height                        0
# income                        0
# job                           0
# last_online                   0
# location                      0
# orientation                   0
# religion                      0
# sex                           0
# sign                          0
# smokes                        0
# status                        0
# number_of_fluent_languages    0
# number_of_poorly_languages    0
# has_animals                   0
# has_kids                      0
# generation                    0
# dtype: int64

# %%
#AUTO ML İLE İLGİLİ İLK KODLARI EN BAŞTA İMPORT ETTİK
#AŞAĞIDA DEVAMI VE ÇÖZÜM VAR

# %%
setup(data=df,target='age')
# Out:
# <style type="text/css">
# #T_1236e_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1236e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1236e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1236e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1236e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1236e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1236e_row0_col1" class="data row0 col1" >494</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1236e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1236e_row1_col1" class="data row1 col1" >age</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1236e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1236e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1236e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1236e_row3_col1" class="data row3 col1" >(9515, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1236e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1236e_row4_col1" class="data row4 col1" >(9515, 88)</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1236e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1236e_row5_col1" class="data row5 col1" >(6660, 88)</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1236e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1236e_row6_col1" class="data row6 col1" >(2855, 88)</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1236e_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_1236e_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1236e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_1236e_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1236e_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_1236e_row9_col1" class="data row9 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1236e_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_1236e_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1236e_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_1236e_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1236e_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_1236e_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1236e_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_1236e_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1236e_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_1236e_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1236e_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_1236e_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1236e_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_1236e_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1236e_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_1236e_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1236e_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_1236e_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1236e_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_1236e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1236e_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_1236e_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1236e_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_1236e_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1236e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1236e_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_1236e_row22_col1" class="data row22 col1" >f1b7</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_578d9 th {
#   text-align: left;
# }
# #T_578d9_row0_col0, #T_578d9_row1_col0, #T_578d9_row1_col1, #T_578d9_row1_col2, #T_578d9_row1_col3, #T_578d9_row1_col4, #T_578d9_row1_col5, #T_578d9_row1_col6, #T_578d9_row2_col0, #T_578d9_row2_col1, #T_578d9_row2_col2, #T_578d9_row2_col3, #T_578d9_row2_col4, #T_578d9_row2_col5, #T_578d9_row2_col6, #T_578d9_row3_col0, #T_578d9_row3_col1, #T_578d9_row3_col2, #T_578d9_row3_col3, #T_578d9_row3_col4, #T_578d9_row3_col5, #T_578d9_row3_col6, #T_578d9_row4_col0, #T_578d9_row4_col1, #T_578d9_row4_col2, #T_578d9_row4_col3, #T_578d9_row4_col4, #T_578d9_row4_col5, #T_578d9_row4_col6, #T_578d9_row5_col0, #T_578d9_row5_col1, #T_578d9_row5_col2, #T_578d9_row5_col3, #T_578d9_row5_col4, #T_578d9_row5_col5, #T_578d9_row5_col6, #T_578d9_row6_col0, #T_578d9_row6_col1, #T_578d9_row6_col2, #T_578d9_row6_col3, #T_578d9_row6_col4, #T_578d9_row6_col5, #T_578d9_row6_col6, #T_578d9_row7_col0, #T_578d9_row7_col1, #T_578d9_row7_col2, #T_578d9_row7_col3, #T_578d9_row7_col4, #T_578d9_row7_col5, #T_578d9_row7_col6, #T_578d9_row8_col0, #T_578d9_row8_col1, #T_578d9_row8_col2, #T_578d9_row8_col3, #T_578d9_row8_col4, #T_578d9_row8_col5, #T_578d9_row8_col6, #T_578d9_row9_col0, #T_578d9_row9_col1, #T_578d9_row9_col2, #T_578d9_row9_col3, #T_578d9_row9_col4, #T_578d9_row9_col5, #T_578d9_row9_col6, #T_578d9_row10_col0, #T_578d9_row10_col1, #T_578d9_row10_col2, #T_578d9_row10_col3, #T_578d9_row10_col4, #T_578d9_row10_col5, #T_578d9_row10_col6, #T_578d9_row11_col0, #T_578d9_row11_col1, #T_578d9_row11_col2, #T_578d9_row11_col3, #T_578d9_row11_col4, #T_578d9_row11_col5, #T_578d9_row11_col6, #T_578d9_row12_col0, #T_578d9_row12_col1, #T_578d9_row12_col2, #T_578d9_row12_col3, #T_578d9_row12_col4, #T_578d9_row12_col5, #T_578d9_row12_col6, #T_578d9_row13_col0, #T_578d9_row13_col1, #T_578d9_row13_col2, #T_578d9_row13_col3, #T_578d9_row13_col4, #T_578d9_row13_col5, #T_578d9_row13_col6, #T_578d9_row14_col0, #T_578d9_row14_col1, #T_578d9_row14_col2, #T_578d9_row14_col3, #T_578d9_row14_col4, #T_578d9_row14_col5, #T_578d9_row14_col6, #T_578d9_row15_col0, #T_578d9_row15_col1, #T_578d9_row15_col2, #T_578d9_row15_col3, #T_578d9_row15_col4, #T_578d9_row15_col5, #T_578d9_row15_col6, #T_578d9_row16_col0, #T_578d9_row16_col1, #T_578d9_row16_col2, #T_578d9_row16_col3, #T_578d9_row16_col4, #T_578d9_row16_col5, #T_578d9_row16_col6, #T_578d9_row17_col0, #T_578d9_row17_col1, #T_578d9_row17_col2, #T_578d9_row17_col3, #T_578d9_row17_col4, #T_578d9_row17_col5, #T_578d9_row17_col6, #T_578d9_row18_col0, #T_578d9_row18_col1, #T_578d9_row18_col2, #T_578d9_row18_col3, #T_578d9_row18_col4, #T_578d9_row18_col5, #T_578d9_row18_col6 {
#   text-align: left;
# }
# #T_578d9_row0_col1, #T_578d9_row0_col2, #T_578d9_row0_col3, #T_578d9_row0_col4, #T_578d9_row0_col5, #T_578d9_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_578d9_row0_col7, #T_578d9_row1_col7, #T_578d9_row2_col7, #T_578d9_row3_col7, #T_578d9_row4_col7, #T_578d9_row5_col7, #T_578d9_row6_col7, #T_578d9_row7_col7, #T_578d9_row8_col7, #T_578d9_row9_col7, #T_578d9_row10_col7, #T_578d9_row11_col7, #T_578d9_row12_col7, #T_578d9_row14_col7, #T_578d9_row15_col7, #T_578d9_row16_col7, #T_578d9_row17_col7, #T_578d9_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_578d9_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_578d9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_578d9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_578d9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_578d9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_578d9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_578d9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_578d9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_578d9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_578d9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_578d9_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_578d9_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_578d9_row0_col1" class="data row0 col1" >3.1877</td>
#       <td id="T_578d9_row0_col2" class="data row0 col2" >14.9581</td>
#       <td id="T_578d9_row0_col3" class="data row0 col3" >3.8667</td>
#       <td id="T_578d9_row0_col4" class="data row0 col4" >0.8332</td>
#       <td id="T_578d9_row0_col5" class="data row0 col5" >0.1209</td>
#       <td id="T_578d9_row0_col6" class="data row0 col6" >0.1051</td>
#       <td id="T_578d9_row0_col7" class="data row0 col7" >0.7670</td>
#     </tr>
#     <tr>
#       <th id="T_578d9_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_578d9_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_578d9_row1_col1" class="data row1 col1" >3.4192</td>
#       <td id="T_578d9_row1_col2" class="data row1 col2" >18.3128</td>
#       <td id="T_578d9_row1_col3" class="data row1 col3" >4.2650</td>
#       <td id="T_578d9_row1_col4" class="data row1 col4" >0.7970</td>
#       <td id="T_578d9_row1_col5" class="data row1 col5" >0.1346</td>
#       <td id="T_578d9_row1_col6" class="data row1 col6" >0.1153</td>
#       <td id="T_578d9_row1_col7" class="data row1 col7" >1.6360</td>
#     </tr>
#     <tr>
#       <th id="T_578d9_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_578d9_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_578d9_row2_col1" class="data row2 col1" >3.4156</td>
#       <td id="T_578d9_row2_col2" class="data row2 col2" >18.3585</td>
#       <td id="T_578d9_row2_col3" class="data row2 col3" >4.2620</td>
#       <td id="T_578d9_row2_col4" class="data row2 col4" >0.7969</td>
#       <td id="T_578d9_row2_col5" class="data row2 col5" >0.1329</td>
#       <td id="T_578d9_row2_col6" class="data row2 col6" >0.1143</td>
#       <td id="T_578d9_row2_col7" class="data row2 col7" >1.2280</td>
#     </tr>
#     <tr>
#       <th id="T_578d9_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_578d9_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_578d9_row3_col1" class="data row3 col1" >3.4107</td>
#       <td id="T_578d9_row3_col2" class="data row3 col2" >18.3812</td>
#       <td id="T_578d9_row3_col3" class="data row3 col3" >4.2832</td>
#       <td id="T_578d9_row3_col4" class="data row3 col4" >0.7955</td>
#       <td id="T_578d9_row3_col5" class="data row3 col5" >0.1339</td>
#       <td id="T_578d9_row3_col6" class="data row3 col6" >0.1142</td>
#       <td id="T_578d9_row3_col7" class="data row3 col7" >4.9920</td>
#     </tr>
#     <tr>
#       <th id="T_578d9_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_578d9_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_578d9_row4_col1" class="data row4 col1" >3.5114</td>
#       <td id="T_578d9_row4_col2" class="data row4 col2" >19.3843</td>
#       <td id="T_578d9_row4_col3" class="data row4 col3" >4.3625</td>
#       <td id="T_578d9_row4_col4" class="data row4 col4" >0.7861</td>
#       <td id="T_578d9_row4_col5" class="data row4 col5" >0.1356</td>
#       <td id="T_578d9_row4_col6" class="data row4 col6" >0.1170</td>
#       <td id="T_578d9_row4_col7" class="data row4 col7" >4.1320</td>
#     </tr>
#     <tr>
#       <th id="T_578d9_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_578d9_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_578d9_row5_col1" class="data row5 col1" >4.0110</td>
#       <td id="T_578d9_row5_col2" class="data row5 col2" >24.9003</td>
#       <td id="T_578d9_row5_col3" class="data row5 col3" >4.9679</td>
#       <td id="T_578d9_row5_col4" class="data row5 col4" >0.7224</td>
#       <td id="T_578d9_row5_col5" class="data row5 col5" >
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
#ADABOOSTREGRESSİON MODELİNE GÖRE YAŞ DOĞRU  TAHMİN ETME ORANI %83

# %%
#Classification

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                white
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit    anything    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job  ...     religion sex  \
# 0    75.0     -1.0               transportation  ...  agnosticism   m
# 1    70.0  80000.0         hospitality / travel  ...  agnosticism   m
# 2    68.0     -1.0                        other  ...  agnosticism   m
# 3    71.0  20000.0                      student  ...  agnosticism   m
# 4    66.0     -1.0  artistic / musical / writer  ...  agnosticism   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#   number_of_fluent_languages number_of_poorly_languages has_animals  has_kids  \
# 0                        1.0                        0.0       False     False
# 1                        1.0                        2.0       False     False
# 2                        1.0                        0.0        True     False
# 3                        1.0                        1.0       False     False
# 4                        1.0                        0.0       False     False
#
#    generation
# 0  Millennial
# 1    Gen X-er
# 2    Gen X-er
# 3  Millennial
# 4  Millennial
#
# [5 rows x 23 columns]

# %%
from pycaret.classification import*

# %%
##'Boomers' 'Gen X-er' 'Millennial'

df['generation'].replace('Boomers',0,inplace=True)
df['generation'].replace('Gen X-er',1,inplace=True)
df['generation'].replace('Millennial',2,inplace=True)

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                white
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit    anything    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job  ...     religion sex  \
# 0    75.0     -1.0               transportation  ...  agnosticism   m
# 1    70.0  80000.0         hospitality / travel  ...  agnosticism   m
# 2    68.0     -1.0                        other  ...  agnosticism   m
# 3    71.0  20000.0                      student  ...  agnosticism   m
# 4    66.0     -1.0  artistic / musical / writer  ...  agnosticism   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#   number_of_fluent_languages number_of_poorly_languages has_animals  has_kids  \
# 0                        1.0                        0.0       False     False
# 1                        1.0                        2.0       False     False
# 2                        1.0                        0.0        True     False
# 3                        1.0                        1.0       False     False
# 4                        1.0                        0.0       False     False
#
#    generation
# 0           2
# 1           1
# 2           1
# 3           2
# 4           2
#
# [5 rows x 23 columns]

# %%
df.to_csv("generation.csv",index=False)

# %%
setup(df,target='generation')
# Out:
# <style type="text/css">
# #T_99b5f_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99b5f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99b5f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99b5f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99b5f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_99b5f_row0_col1" class="data row0 col1" >5544</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99b5f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99b5f_row1_col1" class="data row1 col1" >generation</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99b5f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_99b5f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99b5f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_99b5f_row3_col1" class="data row3 col1" >(9515, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99b5f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_99b5f_row4_col1" class="data row4 col1" >(9515, 86)</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99b5f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_99b5f_row5_col1" class="data row5 col1" >(6660, 86)</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99b5f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_99b5f_row6_col1" class="data row6 col1" >(2855, 86)</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99b5f_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_99b5f_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99b5f_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_99b5f_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99b5f_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_99b5f_row9_col1" class="data row9 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99b5f_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_99b5f_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99b5f_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_99b5f_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99b5f_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_99b5f_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99b5f_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_99b5f_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99b5f_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_99b5f_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99b5f_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_99b5f_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99b5f_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_99b5f_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99b5f_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_99b5f_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99b5f_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_99b5f_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99b5f_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_99b5f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99b5f_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_99b5f_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99b5f_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_99b5f_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99b5f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99b5f_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_99b5f_row22_col1" class="data row22 col1" >4865</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_5d876 th {
#   text-align: left;
# }
# #T_5d876_row0_col0, #T_5d876_row1_col0, #T_5d876_row2_col0, #T_5d876_row3_col0, #T_5d876_row4_col0, #T_5d876_row5_col0, #T_5d876_row5_col1, #T_5d876_row5_col3, #T_5d876_row5_col4, #T_5d876_row5_col5, #T_5d876_row5_col6, #T_5d876_row5_col7, #T_5d876_row6_col0, #T_5d876_row6_col1, #T_5d876_row6_col2, #T_5d876_row6_col3, #T_5d876_row6_col4, #T_5d876_row6_col5, #T_5d876_row6_col6, #T_5d876_row6_col7, #T_5d876_row7_col0, #T_5d876_row7_col1, #T_5d876_row7_col2, #T_5d876_row7_col3, #T_5d876_row7_col4, #T_5d876_row7_col5, #T_5d876_row7_col6, #T_5d876_row7_col7, #T_5d876_row8_col0, #T_5d876_row8_col1, #T_5d876_row8_col2, #T_5d876_row8_col3, #T_5d876_row8_col4, #T_5d876_row8_col5, #T_5d876_row8_col6, #T_5d876_row8_col7, #T_5d876_row9_col0, #T_5d876_row9_col1, #T_5d876_row9_col2, #T_5d876_row9_col3, #T_5d876_row9_col4, #T_5d876_row9_col5, #T_5d876_row9_col6, #T_5d876_row9_col7, #T_5d876_row10_col0, #T_5d876_row10_col1, #T_5d876_row10_col2, #T_5d876_row10_col3, #T_5d876_row10_col4, #T_5d876_row10_col5, #T_5d876_row10_col6, #T_5d876_row10_col7, #T_5d876_row11_col0, #T_5d876_row11_col1, #T_5d876_row11_col2, #T_5d876_row11_col3, #T_5d876_row11_col4, #T_5d876_row11_col5, #T_5d876_row11_col6, #T_5d876_row11_col7, #T_5d876_row12_col0, #T_5d876_row12_col1, #T_5d876_row12_col2, #T_5d876_row12_col3, #T_5d876_row12_col4, #T_5d876_row12_col5, #T_5d876_row12_col6, #T_5d876_row12_col7, #T_5d876_row13_col0, #T_5d876_row13_col1, #T_5d876_row13_col2, #T_5d876_row13_col3, #T_5d876_row13_col4, #T_5d876_row13_col5, #T_5d876_row13_col6, #T_5d876_row13_col7, #T_5d876_row14_col0, #T_5d876_row14_col1, #T_5d876_row14_col2, #T_5d876_row14_col3, #T_5d876_row14_col4, #T_5d876_row14_col5, #T_5d876_row14_col6, #T_5d876_row14_col7 {
#   text-align: left;
# }
# #T_5d876_row0_col1, #T_5d876_row0_col2, #T_5d876_row0_col3, #T_5d876_row0_col4, #T_5d876_row0_col5, #T_5d876_row0_col6, #T_5d876_row0_col7, #T_5d876_row1_col1, #T_5d876_row1_col2, #T_5d876_row1_col3, #T_5d876_row1_col4, #T_5d876_row1_col5, #T_5d876_row1_col6, #T_5d876_row1_col7, #T_5d876_row2_col1, #T_5d876_row2_col2, #T_5d876_row2_col3, #T_5d876_row2_col4, #T_5d876_row2_col5, #T_5d876_row2_col6, #T_5d876_row2_col7, #T_5d876_row3_col1, #T_5d876_row3_col2, #T_5d876_row3_col3, #T_5d876_row3_col4, #T_5d876_row3_col5, #T_5d876_row3_col6, #T_5d876_row3_col7, #T_5d876_row4_col1, #T_5d876_row4_col2, #T_5d876_row4_col3, #T_5d876_row4_col4, #T_5d876_row4_col5, #T_5d876_row4_col6, #T_5d876_row4_col7, #T_5d876_row5_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5d876_row0_col8, #T_5d876_row1_col8, #T_5d876_row2_col8, #T_5d876_row3_col8, #T_5d876_row4_col8, #T_5d876_row5_col8, #T_5d876_row6_col8, #T_5d876_row7_col8, #T_5d876_row8_col8, #T_5d876_row9_col8, #T_5d876_row10_col8, #T_5d876_row11_col8, #T_5d876_row12_col8, #T_5d876_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5d876_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5d876" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d876_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d876_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5d876_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5d876_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5d876_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5d876_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5d876_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5d876_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_5d876_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d876_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_5d876_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_5d876_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_5d876_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_5d876_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5d876_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_5d876_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_5d876_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_5d876_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_5d876_row0_col8" class="data row0 col8" >0.5260</td>
#     </tr>
#     <tr>
#       <th id="T_5d876_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_5d876_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_5d876_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_5d876_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_5d876_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_5d876_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_5d876_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_5d876_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_5d876_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_5d876_row1_col8" class="data row1 col8" >0.8110</td>
#     </tr>
#     <tr>
#       <th id="T_5d876_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_5d876_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_5d876_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_5d876_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_5d876_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_5d876_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_5d876_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_5d876_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_5d876_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_5d876_row2_col8" class="data row2 col8" >2.9970</td>
#     </tr>
#     <tr>
#       <th id="T_5d876_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_5d876_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_5d876_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_5d876_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_5d876_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_5d876_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_5d876_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_5d876_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_5d876_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_5d876_row3_col8" class="data row3 col8" >0.8590</td>
#     </tr>
#     <tr>
#       <th id="T_5d876_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_5d876_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5d876_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_5d876_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_5d876_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_5d876_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_5d876_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_5d876_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_5d876_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_5d876_row4_col8" class="data row4 col8" >1.2550</td>
#     </tr>
#     <tr>
#       <th id="T_5d876_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_5d876_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_5d876_row5_col1" class="data row5 col1" >0.9889</td>
#       <td id="T_5d876_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_5d876_row5_col3" class="data row5 col3" >0.9889</td>
#       <td id="T_5d876_row5_col4" class="data row5 col4" >0.989
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=5544, splitter='best')

# %%
best_model=create_model('dt')
# Out:
# <style type="text/css">
# #T_2b5a1_row10_col0, #T_2b5a1_row10_col1, #T_2b5a1_row10_col2, #T_2b5a1_row10_col3, #T_2b5a1_row10_col4, #T_2b5a1_row10_col5, #T_2b5a1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2b5a1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b5a1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2b5a1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2b5a1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2b5a1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2b5a1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2b5a1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2b5a1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b5a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b5a1_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_2b5a1_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_2b5a1_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_2b5a1_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_2b5a1_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_2b5a1_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_2b5a1_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b5a1_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_2b5a1_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_2b5a1_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_2b5a1_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_2b5a1_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_2b5a1_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_2b5a1_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b5a1_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_2b5a1_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_2b5a1_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_2b5a1_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_2b5a1_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_2b5a1_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_2b5a1_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b5a1_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_2b5a1_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_2b5a1_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_2b5a1_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_2b5a1_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_2b5a1_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_2b5a1_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b5a1_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_2b5a1_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_2b5a1_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_2b5a1_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_2b5a1_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_2b5a1_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_2b5a1_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b5a1_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_2b5a1_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_2b5a1_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_2b5a1_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_2b5a1_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_2b5a1_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_2b5a1_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b5a1_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_2b5a1_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_2b5a1_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_2b5a1_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_2b5a1_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_2b5a1_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_2b5a1_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b5a1_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_2b5a1_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_2b5a1_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_2b5a1_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_2b5a1_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_2b5a1_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_2b5a1_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b5a1_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_2b5a1_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_2b5a1_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_2b5a1_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_2b5a1_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_2b5a1_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_2b5a1_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b5a1_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_2b5a1_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_2b5a1_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_2b5a1_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_2b5a1_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_2b5a1_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_2b5a1_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2b5a1_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_2b5a1_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_2b5a1_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_2b5a1_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_2b5a1_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_2b5a1_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_2b5a1_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b5a1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2b5a1_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_2b5a1_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_2b5a1_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_2b5a1_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plot_model(best_model,plot='feature')

# %%
#İLK 5 CLASSİFİCATİON MODELİNE GÖRE JENERASYON DOĞRU  TAHMİN ETME ORANI %100

# %%
#BİR DE CLUSTER YAPMAK İSTEDİM. UZUN SÜRSEDE SONUÇ GÜZEL ÇIKTI

# %%
# Clustering

# %%
df.head()
# Out:
#     age body_type        diet drinks drugs  education            ethnicity  \
# 0  22.0     curvy    anything    2.0   0.0    working         asian, white
# 1  35.0       fit       other    3.0   1.0    working                white
# 2  38.0       fit    anything    2.0     0  graduated                white
# 3  23.0       fit  vegetarian    2.0     0    working                white
# 4  29.0       fit    anything    2.0   0.0  graduated  asian, black, other
#
#    height   income                          job  ...     religion sex  \
# 0    75.0     -1.0               transportation  ...  agnosticism   m
# 1    70.0  80000.0         hospitality / travel  ...  agnosticism   m
# 2    68.0     -1.0                        other  ...  agnosticism   m
# 3    71.0  20000.0                      student  ...  agnosticism   m
# 4    66.0     -1.0  artistic / musical / writer  ...  agnosticism   m
#
#                                  sign smokes     status  \
# 0                              gemini    2.0     single
# 1                              cancer    0.0     single
# 2  pisces but it doesn&rsquo;t matter    0.0  available
# 3                              pisces    0.0     single
# 4                            aquarius    0.0     single
#
#   number_of_fluent_languages number_of_poorly_languages has_animals  has_kids  \
# 0                        1.0                        0.0       False     False
# 1                        1.0                        2.0       False     False
# 2                        1.0                        0.0        True     False
# 3                        1.0                        1.0       False     False
# 4                        1.0                        0.0       False     False
#
#    generation
# 0           2
# 1           1
# 2           1
# 3           2
# 4           2
#
# [5 rows x 23 columns]

# %%
from pycaret.clustering import*

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_e42bf_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e42bf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e42bf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e42bf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e42bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e42bf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e42bf_row0_col1" class="data row0 col1" >7913</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e42bf_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e42bf_row1_col1" class="data row1 col1" >(9515, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e42bf_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_e42bf_row2_col1" class="data row2 col1" >(9515, 7094)</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e42bf_row3_col0" class="data row3 col0" >Ordinal features</td>
#       <td id="T_e42bf_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e42bf_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_e42bf_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e42bf_row5_col0" class="data row5 col0" >Categorical features</td>
#       <td id="T_e42bf_row5_col1" class="data row5 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e42bf_row6_col0" class="data row6 col0" >Preprocess</td>
#       <td id="T_e42bf_row6_col1" class="data row6 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e42bf_row7_col0" class="data row7 col0" >Imputation type</td>
#       <td id="T_e42bf_row7_col1" class="data row7 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e42bf_row8_col0" class="data row8 col0" >Numeric imputation</td>
#       <td id="T_e42bf_row8_col1" class="data row8 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e42bf_row9_col0" class="data row9 col0" >Categorical imputation</td>
#       <td id="T_e42bf_row9_col1" class="data row9 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e42bf_row10_col0" class="data row10 col0" >Maximum one-hot encoding</td>
#       <td id="T_e42bf_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e42bf_row11_col0" class="data row11 col0" >Encoding method</td>
#       <td id="T_e42bf_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e42bf_row12_col0" class="data row12 col0" >CPU Jobs</td>
#       <td id="T_e42bf_row12_col1" class="data row12 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e42bf_row13_col0" class="data row13 col0" >Use GPU</td>
#       <td id="T_e42bf_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e42bf_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_e42bf_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e42bf_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_e42bf_row15_col1" class="data row15 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e42bf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e42bf_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_e42bf_row16_col1" class="data row16 col1" >ba90</td>
#     </tr>
#   </tbody>
# </table>

# %%
kmeans=create_model('kmeans',4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd9cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd9cf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dd9cf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dd9cf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dd9cf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dd9cf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dd9cf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd9cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd9cf_row0_col0" class="data row0 col0" >0.9004</td>
#       <td id="T_dd9cf_row0_col1" class="data row0 col1" >164030.3358</td>
#       <td id="T_dd9cf_row0_col2" class="data row0 col2" >0.3988</td>
#       <td id="T_dd9cf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dd9cf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dd9cf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="85119ed3-fc7f-4f48-9d51-e334b2992ac2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85119ed3-fc7f-4f48-9d51-e334b2992ac2")) {                    Plotly.newPlot(                        "85119ed3-fc7f-4f48-9d51-e334b2992ac2",                        [{"customdata":[[22.0],[26.0],[37.0],[34.0],[29.0],[30.0],[29.0],[23.0],[27.0],[33.0],[27.0],[23.0],[40.0],[40.0],[23.0],[26.0],[34.0],[24.0],[28.0],[30.0],[37.0],[40.0],[31.0],[58.0],[38.0],[61.0],[37.0],[42.0],[26.0],[32.0],[27.0],[23.0],[57.0],[25.0],[40.0],[25.0],[22.0],[37.0],[36.0],[24.0],[24.0],[24.0],[26.0],[31.0],[24.0],[33.0],[34.0],[29.0],[24.0],[43.0],[26.0],[26.0],[34.0],[26.0],[27.0],[24.0],[34.0],[28.0],[27.0],[29.0],[27.0],[21.0],[57.0],[41.0],[36.0],[45.0],[58.0],[40.0],[22.0],[31.0],[37.0],[55.0],[31.0],[24.0],[36.0],[28.0],[45.0],[28.0],[27.0],[58.0],[31.0],[41.0],[25.0],[32.0],[27.0],[28.0],[19.0],[23.0],[28.0],[42.0],[37.0],[36.0],[54.0],[55.0],[44.0],[21.0],[25.0],[46.0],[59.0],[53.0],[24.0],[41.0],[33.0],[45.0],[37.0],[41.0],[39.0],[20.0],[25.0],[29.0],[33.0],[27.0],[36.0],[28.0],[27.0],[39.0],[41.0],[41.0],[46.0],[28.0],[30.0],[31.0],[23.0],[30.0],[47.0],[24.0],[28.0],[30.0],[29.0],[60.0],[24.0],[37.0],[24.0],[29.0],[35.0],[28.0],[30.0],[30.0],[35.0],[29.0],[22.0],[27.0],[26.0],[66.0],[66.0],[18.0],[40.0],[29.0],[36.0],[28.0],[32.0],[27.0],[32.0],[23.0],[41.0],[27.0],[43.0],[35.0],[52.0],[38.0],[31.0],[34.0],[45.0],[45.0],[32.0],[29.0],[21.0],[37.0],[44.0],[26.0],[27.0],[29.0],[29.0],[45.0],[21.0],[26.0],[31.0],[41.0],[27.0],[24.0],[58.0],[45.0],[38.0],[34.0],[45.0],[25.0],[28.0],[32.0],[26.0],[35.0],[30.0],[23.0],[47.0],[36.0],[39.0],[60.0],[42.0],[26.0],[33.0],[58.0],[29.0],[62.0],[27.0],[24.0],[61.0],[44.0],[26.0],[22.0],[40.0],[25.0],[29.0],[32.0],[25.0],[31.0],[26.0],[23.0],[27.0],[34.0],[24.0],[24.0],[32.0],[28.0],[40.0],[55.0],[35.0],[24.0],[24.0],[35.0],[31.0],[25.0],[28.0],[28.0],[38.0],[32.0],[28.0],[34.0],[27.0],[27.0],[24.0],[25.0],[23.0],[28.0],[34.0],[28.0],[36.0],[50.0],[32.0],[48.0],[27.0],[42.0],[41.0],[22.0],[31.0],[21.0],[52.0],[54.0],[18.0],[22.0],[25.0],[30.0],[39.0],[41.0],[42.0],[27.0],[51.0],[27.0],[30.0],[22.0],[31.0],[29.0],[38.0],[26.0],[36.0],[32.0],[28.0],[31.0],[32.0],[32.0],[32.0],[23.0],[32.0],[45.0],[32.0],[41.0],[24.0],[23.0],[36.0],[36.0],[30.0],[29.0],[36.0],[25.0],[27.0],[27.0],[61.0],[26.0],[39.0],[58.0],[36.0],[40.0],[27.0],[46.0],[49.0],[26.0],[54.0],[48.0],[37.0],[41.0],[32.0],[33.0],[31.0],[37.0],[37.0],[31.0],[52.0],[32.0],[28.0],[30.0],[25.0],[24.0],[40.0],[38.0],[32.0],[32.0],[26.0],[19.0],[20.0],[24.0],[43.0],[29.0],[33.0],[25.0],[28.0],[30.0],[26.0],[27.0],[47.0],[29.0],[26.0],[24.0],[25.0],[24.0],[29.0],[22.0],[50.0],[37.0],[37.0],[24.0],[24.0],[44.0],[27.0],[24.0],[29.0],[24.0],[27.0],[26.0],[58.0],[27.0],[38.0],[20.0],[21.0],[24.0],[42.0],[35.0],[36.0],[61.0],[30.0],[27.0],[27.0],[50.0],[29.0],[29.0],[22.0],[24.0],[26.0],[26.0],[33.0],[20.0],[25.0],[34.0],[23.0],[40.0],[28.0],[19.0],[32.0],[30.0],[37.0],[19.0],[21.0],[25.0],[47.0],[37.0],[32.0],[28.0],[26.0],[31.0],[39.0],[24.0],[26.0],[38.0],[27.0],[33.0],[37.0],[29.0],[60.0],[41.0],[27.0],[25.0],[25.0],[23.0],[25.0],[24.0],[40.0],[23.0],[38.0],[27.0],[28.0],[26.0],[37.0],[52.0],[30.0],[23.0],[40.0],[37.0],[34.0],[35.0],[27.0],[27.0],[26.0],[24.0],[28.0],[24.0],[24.0],[43.0],[34.0],[39.0],[29.0],[48.0],[41.0],[59.0],[33.0],[25.0],[43.0],[28.0],[29.0],[37.0],[23.0],[26.0],[45.0],[35.0],[36.0],[43.0],[28.0],[34.0],[41.0],[48.0],[28.0],[51.0],[26.0],[27.0],[31.0],[26.0],[33.0],[48.0],[23.0],[34.0],[27.0],[33.0],[35.0],[24.0],[29.0],[31.0],[48.0],[31.0],[29.0],[23.0],[24.0],[30.0],[44.0],[33.0],[29.0],[29.0],[22.0],[28.0],[31.0],[26.0],[35.0],[24.0],[32.0 ...

# %%
plot_model(kmeans,plot='elbow')

# %%
plot_model(kmeans,plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b813b224-4df3-463f-a193-6b08931948d4" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b813b224-4df3-463f-a193-6b08931948d4")) {                    Plotly.newPlot(                        "b813b224-4df3-463f-a193-6b08931948d4",                        [{"customdata":[[22.0],[26.0],[37.0],[34.0],[29.0],[30.0],[29.0],[23.0],[27.0],[33.0],[27.0],[23.0],[40.0],[40.0],[23.0],[26.0],[34.0],[24.0],[28.0],[30.0],[37.0],[40.0],[31.0],[58.0],[38.0],[61.0],[37.0],[42.0],[26.0],[32.0],[27.0],[23.0],[57.0],[25.0],[40.0],[25.0],[22.0],[37.0],[36.0],[24.0],[24.0],[24.0],[26.0],[31.0],[24.0],[33.0],[34.0],[29.0],[24.0],[43.0],[26.0],[26.0],[34.0],[26.0],[27.0],[24.0],[34.0],[28.0],[27.0],[29.0],[27.0],[21.0],[57.0],[41.0],[36.0],[45.0],[58.0],[40.0],[22.0],[31.0],[37.0],[55.0],[31.0],[24.0],[36.0],[28.0],[45.0],[28.0],[27.0],[58.0],[31.0],[41.0],[25.0],[32.0],[27.0],[28.0],[19.0],[23.0],[28.0],[42.0],[37.0],[36.0],[54.0],[55.0],[44.0],[21.0],[25.0],[46.0],[59.0],[53.0],[24.0],[41.0],[33.0],[45.0],[37.0],[41.0],[39.0],[20.0],[25.0],[29.0],[33.0],[27.0],[36.0],[28.0],[27.0],[39.0],[41.0],[41.0],[46.0],[28.0],[30.0],[31.0],[23.0],[30.0],[47.0],[24.0],[28.0],[30.0],[29.0],[60.0],[24.0],[37.0],[24.0],[29.0],[35.0],[28.0],[30.0],[30.0],[35.0],[29.0],[22.0],[27.0],[26.0],[66.0],[66.0],[18.0],[40.0],[29.0],[36.0],[28.0],[32.0],[27.0],[32.0],[23.0],[41.0],[27.0],[43.0],[35.0],[52.0],[38.0],[31.0],[34.0],[45.0],[45.0],[32.0],[29.0],[21.0],[37.0],[44.0],[26.0],[27.0],[29.0],[29.0],[45.0],[21.0],[26.0],[31.0],[41.0],[27.0],[24.0],[58.0],[45.0],[38.0],[34.0],[45.0],[25.0],[28.0],[32.0],[26.0],[35.0],[30.0],[23.0],[47.0],[36.0],[39.0],[60.0],[42.0],[26.0],[33.0],[58.0],[29.0],[62.0],[27.0],[24.0],[61.0],[44.0],[26.0],[22.0],[40.0],[25.0],[29.0],[32.0],[25.0],[31.0],[26.0],[23.0],[27.0],[34.0],[24.0],[24.0],[32.0],[28.0],[40.0],[55.0],[35.0],[24.0],[24.0],[35.0],[31.0],[25.0],[28.0],[28.0],[38.0],[32.0],[28.0],[34.0],[27.0],[27.0],[24.0],[25.0],[23.0],[28.0],[34.0],[28.0],[36.0],[50.0],[32.0],[48.0],[27.0],[42.0],[41.0],[22.0],[31.0],[21.0],[52.0],[54.0],[18.0],[22.0],[25.0],[30.0],[39.0],[41.0],[42.0],[27.0],[51.0],[27.0],[30.0],[22.0],[31.0],[29.0],[38.0],[26.0],[36.0],[32.0],[28.0],[31.0],[32.0],[32.0],[32.0],[23.0],[32.0],[45.0],[32.0],[41.0],[24.0],[23.0],[36.0],[36.0],[30.0],[29.0],[36.0],[25.0],[27.0],[27.0],[61.0],[26.0],[39.0],[58.0],[36.0],[40.0],[27.0],[46.0],[49.0],[26.0],[54.0],[48.0],[37.0],[41.0],[32.0],[33.0],[31.0],[37.0],[37.0],[31.0],[52.0],[32.0],[28.0],[30.0],[25.0],[24.0],[40.0],[38.0],[32.0],[32.0],[26.0],[19.0],[20.0],[24.0],[43.0],[29.0],[33.0],[25.0],[28.0],[30.0],[26.0],[27.0],[47.0],[29.0],[26.0],[24.0],[25.0],[24.0],[29.0],[22.0],[50.0],[37.0],[37.0],[24.0],[24.0],[44.0],[27.0],[24.0],[29.0],[24.0],[27.0],[26.0],[58.0],[27.0],[38.0],[20.0],[21.0],[24.0],[42.0],[35.0],[36.0],[61.0],[30.0],[27.0],[27.0],[50.0],[29.0],[29.0],[22.0],[24.0],[26.0],[26.0],[33.0],[20.0],[25.0],[34.0],[23.0],[40.0],[28.0],[19.0],[32.0],[30.0],[37.0],[19.0],[21.0],[25.0],[47.0],[37.0],[32.0],[28.0],[26.0],[31.0],[39.0],[24.0],[26.0],[38.0],[27.0],[33.0],[37.0],[29.0],[60.0],[41.0],[27.0],[25.0],[25.0],[23.0],[25.0],[24.0],[40.0],[23.0],[38.0],[27.0],[28.0],[26.0],[37.0],[52.0],[30.0],[23.0],[40.0],[37.0],[34.0],[35.0],[27.0],[27.0],[26.0],[24.0],[28.0],[24.0],[24.0],[43.0],[34.0],[39.0],[29.0],[48.0],[41.0],[59.0],[33.0],[25.0],[43.0],[28.0],[29.0],[37.0],[23.0],[26.0],[45.0],[35.0],[36.0],[43.0],[28.0],[34.0],[41.0],[48.0],[28.0],[51.0],[26.0],[27.0],[31.0],[26.0],[33.0],[48.0],[23.0],[34.0],[27.0],[33.0],[35.0],[24.0],[29.0],[31.0],[48.0],[31.0],[29.0],[23.0],[24.0],[30.0],[44.0],[33.0],[29.0],[29.0],[22.0],[28.0],[31.0],[26.0],[35.0],[24.0],[32. ...
